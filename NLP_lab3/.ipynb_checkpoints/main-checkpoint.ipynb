# %%
import pandas as pd
import numpy as np
df = pd.read_csv('res/income.csv')

# %%
df
# Out:
#        age         workclass   education  education-num      marital-status  \
# 0       39         State-gov   Bachelors             13       Never-married
# 1       50  Self-emp-not-inc   Bachelors             13  Married-civ-spouse
# 2       38           Private     HS-grad              9            Divorced
# 3       53           Private        11th              7  Married-civ-spouse
# 4       28           Private   Bachelors             13  Married-civ-spouse
# ...    ...               ...         ...            ...                 ...
# 32556   27           Private  Assoc-acdm             12  Married-civ-spouse
# 32557   40           Private     HS-grad              9  Married-civ-spouse
# 32558   58           Private     HS-grad              9             Widowed
# 32559   22           Private     HS-grad              9       Never-married
# 32560   52      Self-emp-inc     HS-grad              9  Married-civ-spouse
#
# ...

# %% [markdown]
# ***Простейший случай с 1 нейроном***

# %%
def linear_regression(df: pd.DataFrame) -> list[float]:
    weights = [0.5] * len(df.columns)
    return df.dot(weights).tolist()

# %% [markdown]
# ***Сигмоида***

# %%
def activation_func(x: list[float]) -> list[float]:
    return [1 / (1 + (2.71828 ** -i)) for i in x]

# %%
def neuron(df: pd.DataFrame):
    temp_result = linear_regression(df)
    result = activation_func(temp_result)
    return result

# %%
if __name__ == "__main__":
    Y = df['income >50K']
    X = df[['age']]
    data = pd.DataFrame({"x1": [0.1, 0.2, 0.3], "x2": [0.4, 0.5, 0.6]})
    predictions = neuron(data)
    print("Predictions:", predictions)
# Out:
# Predictions: [np.float64(0.5621765008857981), np.float64(0.5866175789173301), np.float64(0.610639233949222)]

# %%
import pandas as pd
import numpy as np

# Загружаем данные
df = pd.read_csv('res/income.csv')

def activation_func(x: list[float]) -> list[float]:
    """Функция активации (сигмоида)"""
    return [1 / (1 + (2.71828 ** -i)) for i in x]

def linear_regression(X: pd.DataFrame, weights: list[float]) -> list[float]:
    """Линейная регрессия для предсказания"""
    return X.dot(weights).tolist()

def neuron(df: pd.DataFrame, target_column: str) -> list[float]:
    """Нейрон, использующий линейную регрессию и функцию активации для данных в df"""
    
    # Разделяем df на признаки и целевую переменную
    X = df.drop(columns=[target_column])  # все столбцы, кроме целевой переменной
    Y = df[target_column]  # целевая переменная
    
    # Инициализация весов (например, равными 0.5 для каждого признака)
    weights = [0.5] * int(X.shape[1])
    
    # Получаем линейное предсказание
    temp_result = linear_regression(X, weights)
    
    # Применяем функцию активации
    result = activation_func(temp_result)
    
    return result

if __name__ == "__main__":
    # Предсказания для данных в df
    target_column = 'income >50K'  # Целевая переменная
    predictions = neuron(df, target_column)
    print("Predictions:", predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_917970/3710329761.py in ?()
#      32
#      33 if __name__ == "__main__":
#      34     # Предсказания для данных в df
#      35     target_column = 'income >50K'  # Целевая переменная
# ---> 36     predictions = neuron(df, target_column)
#      37     print("Predictions:", predictions)
#
# /tmp/ipykernel_917970/3710329761.py in ?(df, target_column)
#      22     # Инициализация весов (например, равными 0.5 для каждого признака)
#      23     weights = [0.5] * int(X.shape[1])
#      24
#      25     # Получаем линейное предсказание
# ---> 26     temp_result = linear_regression(X, weights)
#      27
#      28     # Применяем функцию активации
#      29     result = activation_func(temp_result)
#
# /tmp/ipykernel_917970/3710329761.py in ?(X, weights)
# ...
